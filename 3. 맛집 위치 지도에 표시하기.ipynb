# %%
import folium
import pandas as pd
import googlemaps
import numpy as np
from tqdm import tqdm

# %%
df=pd.read_csv('../data/03.best_sandwiches_list_chicago2.csv',index_col=0)
df.head()
# Out:
#                         Cafe               Menu  Price  \
# Rank
# 1                Old Oak Tap                BLT    $10
# 2                  Au Cheval      Fried Bologna     $9
# 3                       Xoco  Woodland Mushroom  $9.50
# 4                  Al’s Deli         Roast Beef  $9.40
# 5     Publican Quality Meats               PB&L    $10
#
#                        Address
# Rank
# 1        2109 W. Chicago Ave.,
# 2         800 W. Randolph St.,
# 3            445 N. Clark St.,
# 4     914 Noyes St., Evanston,
# 5          825 W. Fulton Mkt.,

# %%
gmaps_key='AIzaSyAaHfHEA-ubEJGlFZ6VHc7Y2356tx09iCw'
gmaps=googlemaps.Client(key=gmaps_key)

# %%
lat=[]
lng=[]

for n in tqdm(df.index):
    if df['Address'][n] != 'Multiple':
        target_name=df['Address'][n]+', '+'Chicago'
        gmaps_output=gmaps.geocode(target_name)
        location_output=gmaps_output[0].get('geometry')
        lat.append(location_output['location']['lat'])
        lng.append(location_output['location']['lng'])
        
    else:
        lat.append(np.nan)
        lng.append(np.nan)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [00:07<00:00,  6.81it/s]

# %%
df.head()
# Out:
#                         Cafe               Menu  Price  \
# Rank
# 1                Old Oak Tap                BLT    $10
# 2                  Au Cheval      Fried Bologna     $9
# 3                       Xoco  Woodland Mushroom  $9.50
# 4                  Al’s Deli         Roast Beef  $9.40
# 5     Publican Quality Meats               PB&L    $10
#
#                        Address
# Rank
# 1        2109 W. Chicago Ave.,
# 2         800 W. Randolph St.,
# 3            445 N. Clark St.,
# 4     914 Noyes St., Evanston,
# 5          825 W. Fulton Mkt.,

# %%
len(lat), len(lng)
# Out:
# (50, 50)

# %%
df['lat']=lat
df['lng']=lng

# %%
df.head()
# Out:
#                         Cafe               Menu  Price  \
# Rank
# 1                Old Oak Tap                BLT    $10
# 2                  Au Cheval      Fried Bologna     $9
# 3                       Xoco  Woodland Mushroom  $9.50
# 4                  Al’s Deli         Roast Beef  $9.40
# 5     Publican Quality Meats               PB&L    $10
#
#                        Address        lat        lng
# Rank
# 1        2109 W. Chicago Ave.,  41.895558 -87.679967
# 2         800 W. Randolph St.,  41.884639 -87.647590
# 3            445 N. Clark St.,  41.890523 -87.630783
# 4     914 Noyes St., Evanston,  42.058322 -87.683748
# 5          825 W. Fulton Mkt.,  41.886604 -87.648536

# %%
mapping=folium.Map(location=[df['lat'].mean(), df['lng'].mean()], zoom_start=11)

folium.Marker([df['lat'].mean(), df['lng'].mean()], popup='center').add_to(mapping)

mapping
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e99ba01136fe44e301edad424d619a2c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e99ba01136fe44e301edad424d619a2c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_e99ba01136fe44e301edad424d619a2c = L.map(
#                 &quot;map_e99ba01136fe44e301edad424d619a2c&quot;,
#                 {
#                     center: [41.924247247727266, -87.68097883409092],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0524a4ed45359c9a3d8fe75d8dcaf375 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e99ba01136fe44e301edad424d619a2c);
#
#
#             var marker_c8fbf553a942c678e5194e7786962bab = L.marker(
#                 [41.924247247727266, -87.68097883409092],
#                 {}
#             ).addTo(map_e99ba01136fe44e301edad424d619a2c);
#
#
#         var popup_582f717515bc8880881ccf4fb28b7ab2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_79280fb9a7172b1c9db5845eb87df833 = $(`&lt;div id=&quot;html_79280fb9a7172b1c9db5845eb87df833&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;center&lt;/div&gt;`)[0];
#             popup_582f717515bc8880881ccf4fb28b7ab2.setContent(html_79280fb9a7172b1c9db5845eb87df833);
#
#
#         marker_c8fbf553a942c678e5194e7786962bab.bindPopup(popup_582f717515bc8880881ccf4fb28b7ab2)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
mapping=folium.Map(location=[df['lat'].mean(), df['lng'].mean()], zoom_start=11)

for n in df.index:
    if df['Address'][n] != 'Multiple':
        folium.Marker([df['lat'][n],df['lng'][n]], popup=df['Cafe'][n]).add_to(mapping)

mapping
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_597fc767ec90e713fb3168eea28c9298 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_597fc767ec90e713fb3168eea28c9298&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_597fc767ec90e713fb3168eea28c9298 = L.map(
#                 &quot;map_597fc767ec90e713fb3168eea28c9298&quot;,
#                 {
#                     center: [41.924247247727266, -87.68097883409092],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_93b9c88432bc281f77078e937cf8c942 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_597fc767ec90e713fb3168eea28c9298);
#
#
#             var marker_bd06788c7f696983f2babfc16dc803df = L.marker(
#                 [41.8955577, -87.6799673],
#                 {}
#             ).addTo(map_597fc767ec90e713fb3168eea28c9298);
#
#
#         var popup_bd059cb077a84bc551cf81bbb0c70fde = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_e3d74d2c7a25975e494c68afc1ac7d8a = $(`&lt;div id=&quot;html_e3d74d2c7a25975e494c68afc1ac7d8a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Old Oak Tap&lt;/div&gt;`)[0];
#             popup_bd059cb077a84bc551cf81bbb0c70fde.setContent(html_e3d74d2c7a25975e494c68afc1ac7d8a);
#
#
#         marker_bd06788c7f696983f2babfc16dc803df.bindPopup(popup_bd059cb077a84bc551cf81bbb0c70fde)
#         ;
#
#
#
#
#             var marker_e0828664feda1826fd43bf0b5625eb79 = L.marker(
#                 [41.8846392, -87.6475897],
#                 {}
#             ).addTo(map_597fc767ec90e713fb3168eea28c9298);
#
#
#         var popup_5a882a722e027250718f46133c20f2df = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_77267f64edee353a61b75dd4d7284d0d = $(`&lt;div id=&quot;html_77267f64edee353a61b75dd4d7284d0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Au Cheval&lt;/div&gt;`)[0];
#             popup_5a882a722e027250718f46133c20f2df.setContent(html_77267f64edee353a61b75dd4d7284d0d);
#
#
#         marker_e0828664feda1826fd43bf0b5625eb79.bindPopup(popup_5a882a722e027250718f46133c20f2df)
#         ;
#
#
#
#
#             var marker_f2fab39b210c9c2e29efd122a92dd0f0 = L.marker(
#                 [41.8905226, -87.6307834],
#                 {}
#             ).addTo(map_597fc767ec90e713fb3168eea28c9298);
#
#
#         var popup_9cb357e146fcc185d71c1f91f2e87e33 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_891e14f2d29143ec69d9834f65e3f3ba = $(`&lt;div id=&quot;html_891e14f2d29143ec69d9834f65e3f3ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Xoco&lt;/div&gt;`)[0];
#             popup_9cb357e146fcc185d71c1f91f2e87e33.setContent(html_891e14f2d29143ec69d9834f65e3f3ba);
#
#
#         marker_f2fab39b210c9c2e29efd122a92dd0f0.bindPopup(popup_9cb357e146fcc185d71c1f91f2e87e33)
#         ;
#
#
#
#
#             var marker_ad64a983ae7d28d7f444cfe309b04292 = L.marker(
#                 [42.0583217, -87.6837479],
#                 {}
#             ).addTo(map_597fc767ec90e713fb3168eea28c9298);
#
#
#         var popup_e19d9f53358c08f325f62d76778213aa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d6b043c98d654c481147335a0ac11661 = $(`&lt;div id=&quot;html_d6b043c98d654c481147335a0ac11661&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Al’s Deli&lt;/div&gt;`)[0];
#             popup_e19d9f53358c08f325f62d76778213aa.setContent(html_d6b043c98d654c481147335a0ac11661);
#
#
#         marker_ad64a983ae7d28d7f444cfe309b04292.bindPopup(popup_e19d9f53358c08f325f62d76778213aa)
#         ;
#
#
#
#
#             var marker_3100dde866ab8e48f853dc4933edd16a = L.marker(
#                 [41.8866036, -87.64853649999999],
#                 {}
#             ).addTo(map_597fc767ec90e713fb3168eea28c9298);
#
#
#         var popup_9d18696c86aa2d5647492caa515c63f9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_26459548736dd2c14fbf422f1ca74163 = $(`&lt;div id=&quot;html_26459548736dd2c14fbf422f1ca74163&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Publican Quality Meats&lt;/div&gt;`)[0];
#             popup_9d18696c86aa2d5647492caa515c63f9.setContent(html_26459548736dd2c14fbf422f1ca74163);
#
#
#         marker_3100dde866ab8e48f853dc4933edd16a.bindPopup(popup_9d18696c86aa2d5647492caa515c63f9)
#         ;
#
#
#
#
#             var marker_7120834a0e292460ed971972068d668d = L.marker(
#                 [41.9002501, -87.6250781],
#                 {}
#             ).addTo(map_597fc767ec90e713fb3168eea28c9298);
#
#
#         var popup_e8b63a9b48a3704e796c05680f18bc81 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_43fbd95301a61b487e93f5e9e06e7837 = $(`&lt;div id=&quot;html_43fb
