# %%
import pandas as pd
import numpy as np

# %%
crime_police=pd.read_csv('../data/crime_in_Seoul.csv',encoding='euc-kr')

# %%
crime_police.head()
# Out:
#    구분     죄종 발생검거   건수  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  \
# 0  중부     살인   발생    4         NaN         NaN         NaN         NaN
# 1  중부     살인   검거    4         NaN         NaN         NaN         NaN
# 2  중부     강도   발생    3         NaN         NaN         NaN         NaN
# 3  중부     강도   검거    3         NaN         NaN         NaN         NaN
# 4  중부  강간,추행   발생  109         NaN         NaN         NaN         NaN
#
#    Unnamed: 8
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
crime_police['죄종 및 검거']=crime_police['죄종']+' '+crime_police['발생검거']

# %%
crime_police.head()
# Out:
#    구분     죄종 발생검거   건수  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  \
# 0  중부     살인   발생    4         NaN         NaN         NaN         NaN
# 1  중부     살인   검거    4         NaN         NaN         NaN         NaN
# 2  중부     강도   발생    3         NaN         NaN         NaN         NaN
# 3  중부     강도   검거    3         NaN         NaN         NaN         NaN
# 4  중부  강간,추행   발생  109         NaN         NaN         NaN         NaN
#
#    Unnamed: 8   죄종 및 검거
# 0         NaN     살인 발생
# 1         NaN     살인 검거
# 2         NaN     강도 발생
# 3         NaN     강도 검거
# 4         NaN  강간,추행 발생

# %%
del crime_police['죄종']

# %%
del crime_police['Unnamed: 4']
del crime_police['Unnamed: 5']
del crime_police['Unnamed: 6']
del crime_police['Unnamed: 7']
del crime_police['Unnamed: 8']

# %%
crime_police.head()
# Out:
#    구분 발생검거   건수   죄종 및 검거
# 0  중부   발생    4     살인 발생
# 1  중부   검거    4     살인 검거
# 2  중부   발생    3     강도 발생
# 3  중부   검거    3     강도 검거
# 4  중부   발생  109  강간,추행 발생

# %%
crime_police=crime_police[['구분','죄종 및 검거','건수']]

# %%
crime_police.head()
# Out:
#    구분   죄종 및 검거   건수
# 0  중부     살인 발생    4
# 1  중부     살인 검거    4
# 2  중부     강도 발생    3
# 3  중부     강도 검거    3
# 4  중부  강간,추행 발생  109

# %%
crime_and_police=crime_police.pivot(index='구분',columns='죄종 및 검거',
                                   values='건수')
crime_and_police.reset_index(inplace=True)

# %%
crime_and_police.head()
# Out:
# 죄종 및 검거  구분  강간 검거  강간 발생  강간,추행 검거  강간,추행 발생  강도 검거  강도 발생  살인 검거  살인 발생  \
# 0        강남    NaN    NaN     325.0     428.0   11.0   13.0    6.0    8.0
# 1        강동    NaN    NaN     103.0     124.0    6.0    6.0    3.0    3.0
# 2        강북    NaN    NaN     115.0     136.0    1.0    1.0    4.0    4.0
# 3        강서    NaN    NaN     188.0     246.0    3.0    3.0    7.0    9.0
# 4        관악    NaN    NaN     269.0     321.0    6.0    7.0    4.0    8.0
#
# 죄종 및 검거  절도 검거   절도 발생   폭력 검거   폭력 발생
# 0        737.0  1517.0  1699.0  1961.0
# 1        889.0  1612.0  1461.0  1713.0
# 2        537.0   777.0  1255.0  1383.0
# 3        921.0  1540.0  1925.0  2098.0
# 4        929.0  1860.0  1926.0  2248.0

# %%
crime_and_police.rename(columns={'구분':'관서명'}, inplace=True)

# %%
crime_and_police.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   관서명       31 non-null     object
#  1   강간 검거     5 non-null      float64
#  2   강간 발생     5 non-null      float64
#  3   강간,추행 검거  26 non-null     float64
#  4   강간,추행 발생  26 non-null     float64
#  5   강도 검거     31 non-null     float64
#  6   강도 발생     31 non-null     float64
#  7   살인 검거     31 non-null     float64
#  8   살인 발생     31 non-null     float64
#  9   절도 검거     31 non-null     float64
#  10  절도 발생     31 non-null     float64
#  11  폭력 검거     31 non-null     float64
#  12  폭력 발생     31 non-null     float64
# dtypes: float64(12), object(1)
# memory usage: 3.3+ KB

# %%
! pip install googlemaps

# %%
import googlemaps

# %%
gmaps_key='AIzaSyAaHfHEA-ubEJGlFZ6VHc7Y2356tx09iCw'
gmaps=googlemaps.Client(key=gmaps_key)

# %%
gmaps.geocode('서울혜화경찰서', language='ko')
# Out:
# [{'address_components': [{'long_name': '１１２−１６',
#     'short_name': '１１２−１６',
#     'types': ['premise']},
#    {'long_name': '창경궁로',
#     'short_name': '창경궁로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '종로구',
#     'short_name': '종로구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '03130', 'short_name': '03130', 'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 종로구 창경궁로 112-16',
#   'geometry': {'location': {'lat': 37.5719679, 'lng': 126.9989574},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.57331688029149,
#      'lng': 127.0003063802915},
#     'southwest': {'lat': 37.57061891970849, 'lng': 126.9976084197085}}},
# ...

# %%
station_name=[]

for name in crime_and_police['관서명']:
    station_name.append('서울'+str(name)+'경찰서')
    
station_name
# Out:
# ['서울강남경찰서',
#  '서울강동경찰서',
#  '서울강북경찰서',
#  '서울강서경찰서',
#  '서울관악경찰서',
#  '서울광진경찰서',
#  '서울구로경찰서',
#  '서울금천경찰서',
#  '서울남대문경찰서',
#  '서울노원경찰서',
#  '서울도봉경찰서',
#  '서울동대문경찰서',
#  '서울동작경찰서',
#  '서울마포경찰서',
#  '서울방배경찰서',
#  '서울서대문경찰서',
#  '서울서부경찰서',
#  '서울서초경찰서',
#  '서울성동경찰서',
#  '서울성북경찰서',
#  '서울송파경찰서',
#  '서울수서경찰서',
#  '서울양천경찰서',
#  '서울영등포경찰서',
#  '서울용산경찰서',
#  '서울은평경찰서',
#  '서울종로경찰서',
#  '서울종암경찰서',
#  '서울중랑경찰서',
#  '서울중부경찰서',
#  '서울혜화경찰서']

# %%
station_address=[]
station_lat=[]
station_lng=[]

for name in station_name:
    tmp=gmaps.geocode(name,language='ko')
    station_address.append(tmp[0].get('formatted_address'))
    
    tmp_loc=tmp[0].get('geometry')
    station_lat.append(tmp_loc['location']['lat'])
    station_lng.append(tmp_loc['location']['lng'])
    
    print(name+'-->'+tmp[0].get('formatted_address'))
# Out:
# 서울강남경찰서-->대한민국 서울특별시 강남구 테헤란로114길 11
# 서울강동경찰서-->대한민국 서울특별시 강동구 성
#  37.6533589,
#  37.58506149999999,
#  37.5130866,
#  37.550814,
#  37.4945959,
#  37.5647439,
#  37.6021405,
#  37.4956054,
#  37.5617303,
#  37.58977830000001,
#  37.5016941,
#  37.49349,
#  37.5167711,
#  37.5260441,
#  37.5387099,
#  37.6280204,
#  37.575548,
#  37.6036426,
#  37.6056429,
#  37.56361709999999,
#  37.5719679]

# %%
station_lng
# Out:
# [127.0669578,
#  127.1268224,
#  127.0273399,
#  126.850038,
#  126.9513489,
#  127.083821,
#  126.886731,
#  126.8970429,
#  126.9734981,
#  127.0710473,
#  127.052682,
#  127.0457679,
#  126.9428498,
#  126.954028,
#  126.9831279,
#  126.9667705,
#  126.9213074,
#  127.0052504,
#  127.0364217,
#  127.016589,
#  127.1272481,
#  127.0772119,
#  126.8656996,
#  126.9008091,
#  126.9659183,
#  126.9287899,
#  126.9847471,
#  127.0401328,
#  127.0764866,
#  126.9896517,
#  126.9989574]

# %%
gu_name=[]

for name in station_address:
    tmp=name.split()
    tmp_gu=[gu for gu in tmp if gu[-1]=='구'][0]
    gu_name.append(tmp_gu)
    
crime_and_police['구별']=gu_name
crime_and_police.head()
# Out:
# 죄종 및 검거 관서명  강간 검거  강간 발생  강간,추행 검거  강간,추행 발생  강도 검거  강도 발생  살인 검거  살인 발생  \
# 0        강남    NaN    NaN     325.0     428.0   11.0   13.0    6.0    8.0
# 1        강동    NaN    NaN     103.0     124.0    6.0    6.0    3.0    3.0
# 2        강북    NaN    NaN     115.0     136.0    1.0    1.0    4.0    4.0
# 3        강서    NaN    NaN     188.0     246.0    3.0    3.0    7.0    9.0
# 4        관악    NaN    NaN     269.0     321.0    6.0    7.0    4.0    8.0
#
# 죄종 및 검거  절도 검거   절도 발생   폭력 검거   폭력 발생   구별
# 0        737.0  1517.0  1699.0  1961.0  강남구
# 1        889.0  1612.0  1461.0  1713.0  강동구
# 2        537.0   777.0  1255.0  1383.0  강북구
# 3        921.0  1540.0  1925.0  2098.0  강서구
# 4        929.0  1860.0  1926.0  2248.0  관악구

# %%
crime_and_police.to_csv('../data/crime_in_Seoul_include_gu_name.csv',sep=',',encoding='euc-kr')

# %%
crime_and_police[crime_and_police['구별']=='강남구']
# Out:
# 죄종 및 검거 관서명  강간 검거  강간 발생  강간,추행 검거  강간,추행 발생  강도 검거  강도 발생  살인 검거  살인 발생  \
# 0        강남    NaN    NaN     325.0     428.0   11.0   13.0    6.0    8.0
# 21       수서    NaN    NaN     129.0     150.0   12.0   12.0    5.0    4.0
#
# 죄종 및 검거  절도 검거   절도 발생   폭력 검거   폭력 발생   구별
# 0        737.0  1517.0  1699.0  1961.0  강남구
# 21       423.0   855.0  1050.0  1198.0  강남구
